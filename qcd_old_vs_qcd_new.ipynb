# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # new qcd

# %%
path = '/eos/user/k/kiwoznia/data/VAE_data/VAE_check_run_new_data_training/results/run_39_VAE_G_relu_z10_tsz60.0K_2020-05-25_20:23:22/'

# %%
ff = h5py.File(os.path.join(path,'qcd_side_new_results.h5'),'r')
dat = np.asarray(ff.get('results'))
labels = np.asarray(ff.get('labels'))

# %%
labels
# Out:
# array(['mJJ', 'j1Pt', 'j1Eta', 'j1Phi', 'j1M', 'j1E', 'j2Pt', 'j2M',
#        'j2E', 'DeltaEtaJJ', 'DeltaPhiJJ', 'j1TotalLoss', 'j1RecoLoss',
#        'j1KlLoss', 'j2TotalLoss', 'j2RecoLoss', 'j2KlLoss'], dtype='|S11')

# %%
plt.hist(dat[:,4],bins=100)
plt.title('QCD new j1M')
plt.show()

# %%
plt.hist(dat[:,7],bins=100)
plt.title('QCD new j2M')
plt.show()

# %% [markdown]
# # old qcd

# %%
path = '/eos/user/k/kiwoznia/data/VAE_data/VAE_check_run_old_data_training/results/run_38_VAE_G_relu_z10_tsz60.0K_2020-05-25_18:31:07/'

# %%
ff = h5py.File(os.path.join(path,'qcd_side_old_results.h5'),'r')
dat = np.asarray(ff.get('results'))
labels = np.asarray(ff.get('labels'))

# %%
labels
# Out:
# array(['mJJ', 'j1Pt', 'j1Eta', 'j1Phi', 'j1M', 'j1E', 'j2Pt', 'j2M',
#        'j2E', 'DeltaEtaJJ', 'DeltaPhiJJ', 'j1TotalLoss', 'j1RecoLoss',
#        'j1KlLoss', 'j2TotalLoss', 'j2RecoLoss', 'j2KlLoss'], dtype='|S11')

# %%
plt.hist(dat[:,4],bins=100)
plt.title('QCD new j1M')
plt.show()

# %%
plt.hist(dat[:,7],bins=100)
plt.title('QCD new j2M')
plt.show()
